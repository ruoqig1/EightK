# %%
! pip install -r requirements.txt --no-input
! conda install -c conda-forge -y cudatoolkit=11.2 cudnn=8.1.0
! pip install --upgrade pip
! pip install "tensorflow<2.11"
# Out:
# Requirement already satisfied: didipack in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from -r requirements.txt (line 2)) (4.3.22)
# Requirement already satisfied: linearmodels in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from -r requirements.txt (line 3)) (5.4)
# Requirement already satisfied: pyperclip in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from -r requirements.txt (line 4)) (1.8.2)
# Requirement already satisfied: yfinance in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from -r requirements.txt (line 5)) (0.2.36)
# Requirement already satisfied: html2text in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from -r requirements.txt (line 6)) (2020.1.16)
# Requirement already satisfied: wrds in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from -r requirements.txt (line 7)) (3.1.6)
# Requirement already satisfied: tqdm in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from -r requirements.txt (line 8)) (4.65.0)
# Requirement already satisfied: psutil in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from -r requirements.txt (line 9)) (5.9.0)
# Requirement already satisfied: pillow in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from -r requirements.txt (line 10)) (10.0.1)
# Requirement already satisfied: swifter in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from -r requirements.txt (line 11)) (1.4.0)
# Requirement already satisfied: tensorboard in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from -r requirements.txt (line 12)) (2.15.1)
# Requirement already satisfied: numpy in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from didipack->-r requirements.txt (line 2)) (1.26.3)
# Requirement already satisfied: pandas in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from didipack->-r requirements.txt (line 2)) (2.1.4)
# Requirement already satisfied: statsmodels in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from didipack->-r requirements.txt (line 2)) (0.14.0)
# Requirement already satisfied: matplotlib in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from didipack->-r requirements.txt (line 2)) (3.8.0)
# Requirement already satisfied: jinja2 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from didipack->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: scikit-learn in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from didipack->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from linearmodels->-r requirements.txt (line 3)) (1.11.4)
# Requirement already satisfied: mypy-extensions>=0.4 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from linearmodels->-r requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: Cython>=0.29.37 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from linearmodels->-r requirements.txt (line 3)) (3.0.8)
# Requirement already satisfied: pyhdfe>=0.1 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from linearmodels->-r requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: formulaic>=0.6.5 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from linearmodels->-r requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: setuptools-scm<9.0.0,>=8.0.0 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels->-r requirements.txt (line 3)) (8.0.4)
# Requirement already satisfied: requests>=2.31 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from yfinance->-r requirements.txt (line 5)) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from yfinance->-r requirements.txt (line 5)) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from yfinance->-r requirements.txt (line 5)) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from yfinance->-r requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from yfinance->-r requirements.txt (line 5)) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from yfinance->-r requirements.txt (line 5)) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from yfinance->-r requirements.txt (line 5)) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from yfinance->-r requirements.txt (line 5)) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from yfinance->-r requirements.txt (line 5)) (1.1)
# Requirement already satisfied: psycopg2-binary in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from wrds->-r requirements.txt (line 7)) (2.9.9)
# Requirement already satisfied: sqlalchemy<2 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from wrds->-r requirements.txt (line 7)) (1.4.51)
# Requirement already satisfied: colorama in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from tqdm->-r requirements.txt (line 8)) (0.4.6)
# Requirement already satisfied: dask>=2.10.0 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from dask[dataframe]>=2.10.0->swifter->-r requirements.txt (line 11)) (2023.11.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from tensorboard->-r requirements.txt (line 12)) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from tensorboard->-r requirements.txt (line 12)) (1.60.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from tensorboard->-r requirements.txt (line 12)) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from tensorboard->-r requirements.txt (line 12)) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from tensorboard->-r requirements.txt (line 12)) (3.4.1)
# Requirement already satisfied: protobuf<4.24,>=3.19.6 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from tensorboard->-r requirements.txt (line 12)) (4.23.4)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from tensorboard->-r requirements.txt (line 12)) (68.2.2)
# Requirement already satisfied: six>1.9 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from tensorboard->-r requirements.txt (line 12)) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from tensorboard->-r requirements.txt (line 12)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from tensorboard->-r requirements.txt (line 12)) (2.2.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance->-r requirements.txt (line 5)) (2.5)
# Requirement already satisfied: click>=8.1 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter->-r requirements.txt (line 11)) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter->-r requirements.txt (line 11)) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter->-r requirements.txt (line 11)) (2023.10.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter->-r requirements.txt (line 11)) (23.1)
# Requirement already satisfied: partd>=1.2.0 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter->-r requirements.txt (line 11)) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter->-r requirements.txt (line 11)) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter->-r requirements.txt (line 11)) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter->-r requirements.txt (line 11)) (7.0.1)
# Requirement already satisfied: interface-meta>=1.2.0 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from formulaic>=0.6.5->linearmodels->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from formulaic>=0.6.5->linearmodels->-r requirements.txt (line 3)) (4.9.0)
# Requirement already satisfied: wrapt>=1.0 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from formulaic>=0.6.5->linearmodels->-r requirements.txt (line 3)) (1.14.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 12)) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 12)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 12)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard->-r requirements.txt (line 12)) (1.3.1)
# Requirement already satisfied: webencodings in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from html5lib>=1.1->yfinance->-r requirements.txt (line 5)) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from pandas->didipack->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from pandas->didipack->-r requirements.txt (line 2)) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from requests>=2.31->yfinance->-r requirements.txt (line 5)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from requests>=2.31->yfinance->-r requirements.txt (line 5)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from requests>=2.31->yfinance->-r requirements.txt (line 5)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from requests>=2.31->yfinance->-r requirements.txt (line 5)) (2023.11.17)
# Requirement already satisfied: tomli>=1 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from setuptools-scm<9.0.0,>=8.0.0->setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels->-r requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from sqlalchemy<2->wrds->-r requirements.txt (line 7)) (3.0.1)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from statsmodels->didipack->-r requirements.txt (line 2)) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from werkzeug>=1.0.1->tensorboard->-r requirements.txt (line 12)) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from matplotlib->didipack->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from matplotlib->didipack->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from matplotlib->didipack->-r requirements.txt (line 2)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from matplotlib->didipack->-r requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from matplotlib->didipack->-r requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from scikit-learn->didipack->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from scikit-learn->didipack->-r requirements.txt (line 2)) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from importlib-metadata>=4.13.0->dask>=2.10.0->dask[dataframe]>=2.10.0->swifter->-r requirements.txt (line 11)) (3.17.0)
# Requirement already satisfied: locket in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from partd>=1.2.0->dask>=2.10.0->dask[dataframe]>=2.10.0->swifter->-r requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 12)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard->-r requirements.txt (line 12)) (3.2.2)
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\nxcle\anaconda3\envs\spartan
#
#   added / updated specs:
#     - cudatoolkit=11.2
#     - cudnn=8.1.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.11.17 |       h56e8100_0         151 KB  conda-forge
#     certifi-2023.11.17         |     pyhd8ed1ab_0         155 KB  conda-forge
#     cudatoolkit-11.2.2         |      h933977f_10       879.9 MB  conda-forge
#     cudnn-8.1.0.77             |       h3e0f4f4_0       610.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        1.46 GB
#
# The following NEW packages will be INSTALLED:
#
#   cudatoolkit        conda-forge/win-64::cudatoolkit-11.2.2-h933977f_10
#   cudnn              conda-forge/win-64::cudnn-8.1.0.77-h3e0f4f4_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.12.12~ --> conda-forge::ca-certificates-2023.11.17-h56e8100_0
#   certifi            pkgs/main/win-64::certifi-2023.11.17-~ --> conda-forge/noarch::certifi-2023.11.17-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
#
# certifi-2023.11.17   | 155 KB    |            |   0%
# certifi-2023.11.17   | 155 KB    | #          |  10%
# certifi-2023.11.17   | 155 KB    | ########## | 100%
#
# cudnn-8.1.0.77       | 610.8 MB  |            |   0%
# cudnn-8.1.0.77       | 610.8 MB  |            |   0%
# cudnn-8.1.0.77       | 610.8 MB  |            |   1%
# cudnn-8.1.0.77       | 610.8 MB  | 1          |   1%
# cudnn-8.1.0.77       | 610.8 MB  | 1          |   2%
# cudnn-8.1.0.77       | 610.8 MB  | 1          |   2%
# cudnn-8.1.0.77       | 610.8 MB  | 2          |   2%
# cudnn-8.1.0.77       | 610.8 MB  | 2          |   2%
# cudnn-8.1.0.77       | 610.8 MB  | 2          |   3%
# cudnn-8.1.0.77       | 610.8 MB  | 2          |   3%
# cudnn-8.1.0.77       | 610.8 MB  | 3          |   3%
# cudnn-8.1.0.77       | 610.8 MB  | 3          |   3%
# cudnn-8.1.0.77       | 610.8 MB  | 3          |   4%
# cudnn-8.1.0.77       | 610.8 MB  | 3          |   4%
# cudnn-8.1.0.77       | 610.8 MB  | 4          |   4%
# cudnn-8.1.0.77       | 610.8 MB  | 4          |   4%
# cudnn-8.1.0.77       | 610.8 MB  | 4          |   4%
# cudnn-8.1.0.77       | 610.8 MB  | 4          |   5%
# cudnn-8.1.0.77       | 610.8 MB  | 5          |   5%
# cudnn-8.1.0.77       | 610.8 MB  | 5          |   5%
# cudnn-8.1.0.77       | 610.8 MB  | 5          |   6%
# cudnn-8.1.0.77       | 610.8 MB  | 6          |   6%
# cudnn-8.1.0.77       | 610.8 MB  | 6          |   6%
# cudnn-8.1.0.77       | 610.8 MB  | 6          |   7%
# cudnn-8.1.0.77       | 610.8 MB  | 7          |   7%
# cudnn-8.1.0.77       | 610.8 MB  | 7          |   7%
# cudnn-8.1.0.77       | 610.8 MB  | 7          |   8%
# cudnn-8.1.0.77       | 610.8 MB  | 7          |   8%
# cudnn-8.1.0.77       | 610.8 MB  | 7          |   8%
# cudnn-8.1.0.77       | 610.8 MB  | 8          |   8%
# cudnn-8.1.0.77       | 610.8 MB  | 8          |   8%
# cudnn-8.1.0.77       | 610.8 MB  | 8          |   9%
# cudnn-8.1.0.77       | 610.8 MB  | 8          |   9%
# cudnn-8.1.0.77       | 610.8 MB  | 9          |   9%
# cudnn-8.1.0.77       | 610.8 MB  | 9          |   9%
# cudnn-8.1.0.77       | 610.8 MB  | 9          |  10%
# cudnn-8.1.0.77       | 610.8 MB  | 9          |  10%
# cudnn-8.1.0.77       | 610.8 MB  | #          |  10%
# cudnn-8.1.0.77       | 610.8 MB  | #          |  10%
# cudnn-8.1.0.77       | 610.8 MB  | #          |  10%
# cudnn-8.1.0.77       | 610.8 MB  | #          |  11%
# cudnn-8.1.0.77       | 610.8 MB  | #          |  11%
# cudnn-8.1.0.77       | 610.8 MB  | #1         |  11%
# cudnn-8.1.0.77       | 610.8 MB  | #1         |  11%
# cudnn-8.1.0.77       | 610.8 MB  | #1         |  12%
# cudnn-8.1.0.77       | 610.8 MB  | #1         |  12%
# cudnn-8.1.0.77       | 610.8 MB  | #2         |  12%
# cudnn-8.1.0.77       | 610.8 MB  | #2         |  12%
# cudnn-8.1.0.77       | 610.8 MB  | #2         |  13%
# cudnn-8.1.0.77       | 610.8 MB  | #2         |  13%
# cudnn-8.1.0.77       | 610.8 MB  | #2         |  13%
# cudnn-8.1.0.77       | 610.8 MB  | #3         |  13%
# cudnn-8.1.0.77       | 610.8 MB  | #3         |  13%
# cudnn-8.1.0.77       | 610.8 MB  | #3         |  14%
# cudnn-8.1.0.77       | 610.8 MB  | #3         |  14%
# cudnn-8.1.0.77       | 610.8 MB  | #4         |  14%
# cudnn-8.1.0.77       | 610.8 MB  | #4         |  14%
# cudnn-8.1.0.77       | 610.8 MB  | #4         |  15%
# cudnn-8.1.0.77       | 610.8 MB  | #4         |  15%
# cudnn-8.1.0.77       | 610.8 MB  | #5         |  15%
# cudnn-8.1.0.77       | 610.8 MB  | #5         |  15%
# cudnn-8.1.0.77       | 610.8 MB  | #5         |  15%
# cudnn-8.1.0.77       | 610.8 MB  | #5         |  16%
# cudnn-8.1.0.77       | 610.8 MB  | #5         |  16%
# cudnn-8.1.0.77       | 610.8 MB  | #6         |  16%
# cudnn-8.1.0.77       | 610.8 MB  | #6         |  16%
# cudnn-8.1.0.77       | 610.8 MB  | #6         |  17%
# cudnn-8.1.0.77       | 610.8 MB  | #6         |  17%
# cudnn-8.1.0.77       | 610.8 MB  | #7         |  17%
# cudnn-8.1.0.77       | 610.8 MB  | #7         |  17%
# cudnn-8.1.0.77       | 610.8 MB  | #7         |  18%
# cudnn-8.1.0.77       | 610.8 MB  | #7         |  18%
# cudnn-8.1.0.77       | 610.8 MB  | #8         |  18%
# cudnn-8.1.0.77       | 610.8 MB  | #8         |  18%
# cudnn-8.1.0.77       | 610.8 MB  | #8         |  19%
# cudnn-8.1.0.77       | 610.8 MB  | #8         |  19%
# cudnn-8.1.0.77       | 610.8 MB  | #9         |  19%
# cudnn-8.1.0.77       | 610.8 MB  | #9         |  19%
# cudnn-8.1.0.77       | 610.8 MB  | #9         |  19%
# cudnn-8.1.0.77       | 610.8 MB  | #9         |  20%
# cudnn-8.1.0.77       | 610.8 MB  | #9         |  20%
# cudnn-8.1.0.77       | 610.8 MB  | ##         |  20%
# cudnn-8.1.0.77       | 610.8 MB  | ##         |  20%
# cudnn-8.1.0.77       | 610.8 MB  | ##         |  21%
# cudnn-8.1.0.77       | 610.8 MB  | ##         |  21%
# cudnn-8.1.0.77       | 610.8 MB  | ##1        |  21%
# cudnn-8.1.0.77       | 610.8 MB  | ##1        |  21%
# cudnn-8.1.0.77       | 610.8 MB  | ##1        |  21%
# cudnn-8.1.0.77       | 610.8 MB  | ##1        |  22%
# cudnn-8.1.0.77       | 610.8 MB  | ##1        |  22%
# cudnn-8.1.0.77       | 610.8 MB  | ##2        |  22%
# cudnn-8.1.0.77       | 610.8 MB  | ##2        |  22%
# cudnn-8.1.0.77       | 610.8 MB  | ##2        |  23%
# cudnn-8.1.0.77       | 610.8 MB  | ##2        |  23%
# cudnn-8.1.0.77       | 610.8 MB  | ##3        |  23%
# cudnn-8.1.0.77       | 610.8 MB  | ##3        |  23%
# cudnn-8.1.0.77       | 610.8 MB  | ##3        |  24%
# cudnn-8.1.0.77       | 610.8 MB  | ##3        |  24%
# cudnn-8.1.0.77       | 610.8 MB  | ##4        |  24%
# cudnn-8.1.0.77       | 610.8 MB  | ##4        |  24%
# cudnn-8.1.0.77       | 610.8 MB  | ##4        |  24%
# cudnn-8.1.0.77       | 610.8 MB  | ##4        |  25%
# cudnn-8.1.0.77       | 610.8 MB  | ##4        |  25%
# cudnn-8.1.0.77       | 610.8 MB  | ##5        |  25%
# cudnn-8.1.0.77       | 610.8 MB  | ##5        |  25%
# cudnn-8.1.0.77       | 610.8 MB  | ##5        |  26%
# cudnn-8.1.0.77       | 610.8 MB  | ##5        |  26%
# cudnn-8.1.0.77       | 610.8 MB  | ##6        |  26%
# cudnn-8.1.0.77       | 610.8 MB  | ##6        |  26%
# cudnn-8.1.0.77       | 610.8 MB  | ##6        |  27%
# cudnn-8.1.0.77       | 610.8 MB  | ##6        |  27%
# cudnn-8.1.0.77       | 610.8 MB  | ##7        |  27%
# cudnn-8.1.0.77       | 610.8 MB  | ##7        |  27%
# cudnn-8.1.0.77       | 610.8 MB  | ##7        |  28%
# cudnn-8.1.0.77       | 610.8 MB  | ##7        |  28%
# cudnn-8.1.0.77       | 610.8 MB  | ##7        |  28%
# cudnn-8.1.0.77       | 610.8 MB  | ##8        |  28%
# cudnn-8.1.0.77       | 610.8 MB  | ##8        |  28%
# cudnn-8.1.0.77       | 610.8 MB  | ##8        |  29%
# cudnn-8.1.0.77       | 610.8 MB  | ##8        |  29%
# cudnn-8.1.0.77       | 610.8 MB  | ##9        |  29%
# cudnn-8.1.0.77       | 610.8 MB  | ##9        |  29%
# cudnn-8.1.0.77       | 610.8 MB  | ##9        |  30%
# cudnn-8.1.0.77       | 610.8 MB  | ##9        |  30%
# cudnn-8.1.0.77       | 610.8 MB  | ###        |  30%
# cudnn-8.1.0.77       | 610.8 MB  | ###        |  30%
# cudnn-8.1.0.77       | 610.8 MB  | ###        |  31%
# cudnn-8.1.0.77       | 610.8 MB  | ###        |  31%
# cudnn-8.1.0.77       | 610.8 MB  | ###1       |  31%
# cudnn-8.1.0.77       | 610.8 MB  | ###1       |  31%
# cudnn-8.1.0.77       | 610.8 MB  | ###1       |  32%
# cudnn-8.1.0.77       | 610.8 MB  | ###2       |  32%
# cudnn-8.1.0.77       | 610.8 MB  | ###2       |  32%
# cudnn-8.1.0.77       | 610.8 MB  | ###2       |  33%
# cudnn-8.1.0.77       | 610.8 MB  | ###2       |  33%
# cudnn-8.1.0.77       | 610.8 MB  | ###3       |  33%
# cudnn-8.1.0.77       | 610.8 MB  | ###3       |  33%
# cudnn-8.1.0.77       | 610.8 MB  | ###3       |  34%
# cudnn-8.1.0.77       | 610.8 MB  | ###3       |  34%
# cudnn-8.1.0.77       | 610.8 MB  | ###4       |  34%
# cudnn-8.1.0.77       | 610.8 MB  | ###4       |  34%
# cudnn-8.1.0.77       | 610.8 MB  | ###4       |  34%
# cudnn-8.1.0.77       | 610.8 MB  | ###4       |  35%
# cudnn-8.1.0.77       | 610.8 MB  | ###4       |  35%
# cudnn-8.1.0.77       | 610.8 MB  | ###5       |  35%
# cudnn-8.1.0.77       | 610.8 MB  | ###5       |  36%
# cudnn-8.1.0.77       | 610.8 MB  | ###5       |  36%
# cudnn-8.1.0.77       | 610.8 MB  | ###5       |  36%
# cudnn-8.1.0.77       | 610.8 MB  | ###6       |  36%
# cudnn-8.1.0.77       | 610.8 MB  | ###6       |  36%
# cudnn-8.1.0.77       | 610.8 MB  | ###6       |  37%
# cudnn-8.1.0.77       | 610.8 MB  | ###6       |  37%
# cudnn-8.1.0.77       | 610.8 MB  | ###7       |  37%
# cudnn-8.1.0.77       | 610.8 MB  | ###7       |  37%
# cudnn-8.1.0.77       | 610.8 MB  | ###7       |  38%
# cudnn-8.1.0.77       | 610.8 MB  | ###7       |  38%
# cudnn-8.1.0.77       | 610.8 MB  | ###7       |  38%
# cudnn-8.1.0.77       | 610.8 MB  | ###8       |  38%
# cudnn-8.1.0.77       | 610.8 MB  | ###8       |  38%
# cudnn-8.1.0.77       | 610.8 MB  | ###8       |  39%
# cudnn-8.1.0.77       | 610.8 MB  | ###8       |  39%
# cudnn-8.1.0.77       | 610.8 MB  | ###9       |  39%
# cudnn-8.1.0.77       | 610.8 MB  | ###9       |  39%
# cudnn-8.1.0.77       | 610.8 MB  | ###9       |  40%
# cudnn-8.1.0.77       | 610.8 MB  | ###9       |  40%
# cudnn-8.1.0.77       | 610.8 MB  | ####       |  40%
# cudnn-8.1.0.77       | 610.8 MB  | ####       |  40%
# cudnn-8.1.0.77       | 610.8 MB  | ####       |  41%
# cudnn-8.1.0.77       | 610.8 MB  | ####       |  41%
# cudnn-8.1.0.77       | 610.8 MB  | ####1      |  41%
# cudnn-8.1.0.77       | 610.8 MB  | ####1      |  41%
# cudnn-8.1.0.77       | 610.8 MB  | ####1      |  41%
# cudnn-8.1.0.77       | 610.8 MB  | ####1      |  42%
# cudnn-8.1.0.77       | 610.8 MB  | ####1      |  42%
# cudnn-8.1.0.77       | 610.8 MB  | ####2      |  42%
# cudnn-8.1.0.77       | 610.8 MB  | ####2      |  42%
# cudnn-8.1.0.77       | 610.8 MB  | ####2      |  43%
# cudnn-8.1.0.77       | 610.8 MB  | ####2      |  43%
# cudnn-8.1.0.77       | 610.8 MB  | ####3      |  43%
# cudnn-8.1.0.77       | 610.8 MB  | ####3      |  43%
# cudnn-8.1.0.77       | 610.8 MB  | ####3      |  44%
# cudnn-8.1.0.77       | 610.8 MB  | ####3      |  44%
# cudnn-8.1.0.77       | 610.8 MB  | ####4      |  44%
# cudnn-8.1.0.77       | 610.8 MB  | ####4      |  44%
# cudnn-8.1.0.77       | 610.8 MB  | ####4      |  45%
# cudnn-8.1.0.77       | 610.8 MB  | ####4      |  45%
# cudnn-8.1.0.77       | 610.8 MB  | ####4      |  45%
# cudnn-8.1.0.77       | 610.8 MB  | ####5      |  45%
# cudnn-8.1.0.77       | 610.8 MB  | ####5      |  45%
# cudnn-8.1.0.77       | 610.8 MB  | ####5      |  46%
# cudnn-8.1.0.77       | 610.8 MB  | ####5      |  46%
# cudnn-8.1.0.77       | 610.8 MB  | ####6      |  46%
# cudnn-8.1.0.77       | 610.8 MB  | ####6      |  46%
# cudnn-8.1.0.77       | 610.8 MB  | ####6      |  47%
# cudnn-8.1.0.77       | 610.8 MB  | ####6      |  47%
# cudnn-8.1.0.77       | 610.8 MB  | ####7      |  47%
# cudnn-8.1.0.77       | 610.8 MB  | ####7      |  47%
# cudnn-8.1.0.77       | 610.8 MB  | ####7      |  48%
# cudnn-8.1.0.77       | 610.8 MB  | ####7      |  48%
# cudnn-8.1.0.77       | 610.8 MB  | ####8      |  48%
# cudnn-8.1.0.77       | 610.8 MB  | ####8      |  48%
# cudnn-8.1.0.77       | 610.8 MB  | ####8      |  48%
# cudnn-8.1.0.77       | 610.8 MB  | ####8      |  49%
# cudnn-8.1.0.77       | 610.8 MB  | ####8      |  49%
# cudnn-8.1.0.77       | 610.8 MB  | ####9      |  49%
# cudnn-8.1.0.77       | 610.8 MB  | ####9      |  49%
# cudnn-8.1.0.77       | 610.8 MB  | ####9      |  50%
# cudnn-8.1.0.77       | 610.8 MB  | ####9      |  50%
# cudnn-8.1.0.77       | 610.8 MB  | #####      |  50%
# cudnn-8.1.0.77       | 610.8 MB  | #####      |  50%
# cudnn-8.1.0.77       | 610.8 MB  | #####      |  51%
# cudnn-8.1.0.77       | 610.8 MB  | #####      |  51%
# cudnn-8.1.0.77       | 610.8 MB  | #####1     |  51%
# cudnn-8.1.0.77       | 610.8 MB  | #####1     |  51%
# cudnn-8.1.0.77       | 610.8 MB  | #####1     |  51%
# cudnn-8.1.0.77       | 610.8 MB  | #####1     |  52%
# cudnn-8.1.0.77       | 610.8 MB  | #####1     |  52%
# cudnn-8.1.0.77       | 610.8 MB  | #####2     |  52%
# cudnn-8.1.0.77       | 610.8 MB  | #####2     |  52%
# cudnn-8.1.0.77       | 610.8 MB  | #####2     |  53%
# cudnn-8.1.0.77       | 610.8 MB  | #####2     |  53%
# cudnn-8.1.0.77       | 610.8 MB  | #####3     |  53%
# cudnn-8.1.0.77       | 610.8 MB  | #####3     |  53%
# cudnn-8.1.0.77       | 610.8 MB  | #####3     |  54%
# cudnn-8.1.0.77       | 610.8 MB  | #####3     |  54%
# cudnn-8.1.0.77       | 610.8 MB  | #####4     |  54%
# cudnn-8.1.0.77       | 610.8 MB  | #####4     |  54%
# cudnn-8.1.0.77       | 610.8 MB  | #####4     |  55%
# cudnn-8.1.0.77       | 610.8 MB  | #####4     |  55%
# cudnn-8.1.0.77       | 610.8 MB  | #####4     |  55%
# cudnn-8.1.0.77       | 610.8 MB  | #####5     |  55%
# cudnn-8.1.0.77       | 610.8 MB  | #####5     |  55%
# cudnn-8.1.0.77       | 610.8 MB  | #####5     |  56%
# cudnn-8.1.0.77       | 610.8 MB  | #####5     |  56%
# cudnn-8.1.0.77       | 610.8 MB  | #####6     |  56%
# cudnn-8.1.0.77       | 610.8 MB  | #####6     |  56%
# cudnn-8.1.0.77       | 610.8 MB  | #####6     |  57%
# cudnn-8.1.0.77       | 610.8 MB  | #####6     |  57%
# cudnn-8.1.0.77       | 610.8 MB  | #####7     |  57%
# cudnn-8.1.0.77       | 610.8 MB  | #####7     |  57%
# cudnn-8.1.0.77       | 610.8 MB  | #####7     |  58%
# cudnn-8.1.0.77       | 610.8 MB  | #####7     |  58%
# cudnn-8.1.0.77       | 610.8 MB  | #####7     |  58%
# cudnn-8.1.0.77       | 610.8 MB  | #####8     |  58%
# cudnn-8.1.0.77       | 610.8 MB  | #####8     |  58%
# cudnn-8.1.0.77       | 610.8 MB  | #####8     |  59%
# cudnn-8.1.0.77       | 610.8 MB  | #####8     |  59%
# cudnn-8.1.0.77       | 610.8 MB  | #####9     |  59%
# cudnn-8.1.0.77       | 610.8 MB  | #####9     |  59%
# cudnn-8.1.0.77       | 610.8 MB  | #####9     |  60%
# cudnn-8.1.0.77       | 610.8 MB  | #####9     |  60%
# cudnn-8.1.0.77       | 610.8 MB  | ######     |  60%
# cudnn-8.1.0.77       | 610.8 MB  | ######     |  60%
# cudnn-8.1.0.77       | 610.8 MB  | ######     |  61%
# cudnn-8.1.0.77       | 610.8 MB  | ######     |  61%
# cudnn-8.1.0.77       | 610.8 MB  | ######1    |  61%
# cudnn-8.1.0.77       | 610.8 MB  | ######1    |  61%
# cudnn-8.1.0.77       | 610.8 MB  | ######1    |  61%
# cudnn-8.1.0.77       | 610.8 MB  | ######1    |  62%
# cudnn-8.1.0.77       | 610.8 MB  | ######1    |  62%
# cudnn-8.1.0.77       | 610.8 MB  | ######2    |  62%
# cudnn-8.1.0.77       | 610.8 MB  | ######2    |  62%
# cudnn-8.1.0.77       | 610.8 MB  | ######2    |  63%
# cudnn-8.1.0.77       | 610.8 MB  | ######2    |  63%
# cudnn-8.1.0.77       | 610.8 MB  | ######3    |  63%
# cudnn-8.1.0.77       | 610.8 MB  | ######3    |  63%
# cudnn-8.1.0.77       | 610.8 MB  | ######3    |  63%
# cudnn-8.1.0.77       | 610.8 MB  | ######3    |  64%
# cudnn-8.1.0.77       | 610.8 MB  | ######3    |  64%
# cudnn-8.1.0.77       | 610.8 MB  | ######4    |  64%
# cudnn-8.1.0.77       | 610.8 MB  | ######4    |  64%
# cudnn-8.1.0.77       | 610.8 MB  | ######4    |  65%
# cudnn-8.1.0.77       | 610.8 MB  | ######4    |  65%
# cudnn-8.1.0.77       | 610.8 MB  | ######5    |  65%
# cudnn-8.1.0.77       | 610.8 MB  | ######5    |  65%
# cudnn-8.1.0.77       | 610.8 MB  | ######5    |  66%
# cudnn-8.1.0.77       | 610.8 MB  | ######5    |  66%
# cudnn-8.1.0.77       | 610.8 MB  | ######6    |  66%
# cudnn-8.1.0.77       | 610.8 MB  | ######6    |  66%
# cudnn-8.1.0.77       | 610.8 MB  | ######6    |  67%
# cudnn-8.1.0.77       | 610.8 MB  | ######6    |  67%
# cudnn-8.1.0.77       | 610.8 MB  | ######6    |  67%
# cudnn-8.1.0.77       | 610.8 MB  | ######7    |  67%
# cudnn-8.1.0.77       | 610.8 MB  | ######7    |  67%
# cudnn-8.1.0.77       | 610.8 MB  | ######7    |  68%
# cudnn-8.1.0.77       | 610.8 MB  | ######7    |  68%
# cudnn-8.1.0.77       | 610.8 MB  | ######8    |  68%
# cudnn-8.1.0.77       | 610.8 MB  | ######8    |  68%
# cudnn-8.1.0.77       | 610.8 MB  | ######8    |  69%
# cudnn-8.1.0.77       | 610.8 MB  | ######8    |  69%
# cudnn-8.1.0.77       | 610.8 MB  | ######9    |  69%
# cudnn-8.1.0.77       | 610.8 MB  | ######9    |  69%
# cudnn-8.1.0.77       | 610.8 MB  | ######9    |  70%
# cudnn-8.1.0.77       | 610.8 MB  | ######9    |  70%
# cudnn-8.1.0.77       | 610.8 MB  | ######9    |  70%
# cudnn-8.1.0.77       | 610.8 MB  | #######    |  70%
# cudnn-8.1.0.77       | 610.8 MB  | #######    |  70%
# cudnn-8.1.0.77       | 610.8 MB  | #######    |  71%
# cudnn-8.1.0.77       | 610.8 MB  | #######    |  71%
# cudnn-8.1.0.77       | 610.8 MB  | #######1   |  71%
# cudnn-8.1.0.77       | 610.8 MB  | #######1   |  71%
# cudnn-8.1.0.77       | 610.8 MB  | #######1   |  72%
# cudnn-8.1.0.77       | 610.8 MB  | #######1   |  72%
# cudnn-8.1.0.77       | 610.8 MB  | #######2   |  72%
# cudnn-8.1.0.77       | 610.8 MB  | #######2   |  72%
# cudnn-8.1.0.77       | 610.8 MB  | #######2   |  73%
# cudnn-8.1.0.77       | 610.8 MB  | #######2   |  73%
# cudnn-8.1.0.77       | 610.8 MB  | #######3   |  73%
# cudnn-8.1.0.77       | 610.8 MB  | #######3   |  73%
# cudnn-8.1.0.77       | 610.8 MB  | #######3   |  73%
# cudnn-8.1.0.77       | 610.8 MB  | #######3   |  74%
# cudnn-8.1.0.77       | 610.8 MB  | #######3   |  74%
# cudnn-8.1.0.77       | 610.8 MB  | #######4   |  74%
# cudnn-8.1.0.77       | 610.8 MB  | #######4   |  74%
# cudnn-8.1.0.77       | 610.8 MB  | #######4   |  75%
# cudnn-8.1.0.77       | 610.8 MB  | #######4   |  75%
# cudnn-8.1.0.77       | 610.8 MB  | #######5   |  75%
# cudnn-8.1.0.77       | 610.8 MB  | #######5   |  75%
# cudnn-8.1.0.77       | 610.8 MB  | #######5   |  75%
# cudnn-8.1.0.77       | 610.8 MB  | #######5   |  76%
# cudnn-8.1.0.77       | 610.8 MB  | #######5   |  76%
# cudnn-8.1.0.77       | 610.8 MB  | #######6   |  76%
# cudnn-8.1.0.77       | 610.8 MB  | #######6   |  76%
# cudnn-8.1.0.77       | 610.8 MB  | #######6   |  77%
# cudnn-8.1.0.77       | 610.8 MB  | #######6   |  77%
# cudnn-8.1.0.77       | 610.8 MB  | #######7   |  77%
# cudnn-8.1.0.77       | 610.8 MB  | #######7   |  77%
# cudnn-8.1.0.77       | 610.8 MB  | #######7   |  78%
# cudnn-8.1.0.77       | 610.8 MB  | #######7   |  78%
# cudnn-8.1.0.77       | 610.8 MB  | #######7   |  78%
# cudnn-8.1.0.77       | 610.8 MB  | #######8   |  78%
# cudnn-8.1.0.77       | 610.8 MB  | #######8   |  78%
# cudnn-8.1.0.77       | 610.8 MB  | #######8   |  79%
# cudnn-8.1.0.77       | 610.8 MB  | #######8   |  79%
# cudnn-8.1.0.77       | 610.8 MB  | #######9   |  79%
# cudnn-8.1.0.77       | 610.8 MB  | #######9   |  79%
# cudnn-8.1.0.77       | 610.8 MB  | #######9   |  80%
# cudnn-8.1.0.77       | 610.8 MB  | #######9   |  80%
# cudnn-8.1.0.77       | 610.8 MB  | #######9   |  80%
# cudnn-8.1.0.77       | 610.8 MB  | ########   |  80%
# cudnn-8.1.0.77       | 610.8 MB  | ########   |  80%
# cudnn-8.1.0.77       | 610.8 MB  | ########   |  81%
# cudnn-8.1.0.77       | 610.8 MB  | ########   |  81%
# cudnn-8.1.0.77       | 610.8 MB  | ########1  |  81%
# cudnn-8.1.0.77       | 610.8 MB  | ########1  |  81%
# cudnn-8.1.0.77       | 610.8 MB  | ########1  |  82%
# cudnn-8.1.0.77       | 610.8 MB  | ########1  |  82%
# cudnn-8.1.0.77       | 610.8 MB  | ########2  |  82%
# cudnn-8.1.0.77       | 610.8 MB  | ########2  |  82%
# cudnn-8.1.0.77       | 610.8 MB  | ########2  |  82%
# cudnn-8.1.0.77       | 610.8 MB  | ########2  |  83%
# cudnn-8.1.0.77       | 610.8 MB  | ########2  |  83%
# cudnn-8.1.0.77       | 610.8 MB  | ########3  |  83%
# cudnn-8.1.0.77       | 610.8 MB  | ########3  |  83%
# cudnn-8.1.0.77       | 610.8 MB  | ########3  |  84%
# cudnn-8.1.0.77       | 610.8 MB  | ########3  |  84%
# cudnn-8.1.0.77       | 610.8 MB  | ########3  |  84%
# cudnn-8.1.0.77       | 610.8 MB  | ########4  |  84%
# cudnn-8.1.0.77       | 610.8 MB  | ########4  |  84%
# cudnn-8.1.0.77       | 610.8 MB  | ########4  |  85%
# cudnn-8.1.0.77       | 610.8 MB  | ########4  |  85%
# cudnn-8.1.0.77       | 610.8 MB  | ########5  |  85%
# cudnn-8.1.0.77       | 610.8 MB  | ########5  |  85%
# cudnn-8.1.0.77       | 610.8 MB  | ########5  |  86%
# cudnn-8.1.0.77       | 610.8 MB  | ########5  |  86%
# cudnn-8.1.0.77       | 610.8 MB  | ########6  |  86%
# cudnn-8.1.0.77       | 610.8 MB  | ########6  |  86%
# cudnn-8.1.0.77       | 610.8 MB  | ########6  |  86%
# cudnn-8.1.0.77       | 610.8 MB  | ########6  |  87%
# cudnn-8.1.0.77       | 610.8 MB  | ########6  |  87%
# cudnn-8.1.0.77       | 610.8 MB  | ########7  |  87%
# cudnn-8.1.0.77       | 610.8 MB  | ########7  |  87%
# cudnn-8.1.0.77       | 610.8 MB  | ########7  |  88%
# cudnn-8.1.0.77       | 610.8 MB  | ########7  |  88%
# cudnn-8.1.0.77       | 610.8 MB  | ########8  |  88%
# cudnn-8.1.0.77       | 610.8 MB  | ########8  |  88%
# cudnn-8.1.0.77       | 610.8 MB  | ########8  |  89%
# cudnn-8.1.0.77       | 610.8 MB  | ########8  |  89%
# cudnn-8.1.0.77       | 610.8 MB  | ########9  |  89%
# cudnn-8.1.0.77       | 610.8 MB  | ########9  |  89%
# cudnn-8.1.0.77       | 610.8 MB  | ########9  |  90%
# cudnn-8.1.0.77       | 610.8 MB  | ########9  |  90%
# cudnn-8.1.0.77       | 610.8 MB  | #########  |  90%
# cudnn-8.1.0.77       | 610.8 MB  | #########  |  90%
# cudnn-8.1.0.77       | 610.8 MB  | #########  |  91%
# cudnn-8.1.0.77       | 610.8 MB  | #########1 |  91%
# cudnn-8.1.0.77       | 610.8 MB  | #########1 |  91%
# cudnn-8.1.0.77       | 610.8 MB  | #########1 |  92%
# cudnn-8.1.0.77       | 610.8 MB  | #########1 |  92%
# cudnn-8.1.0.77       | 610.8 MB  | #########2 |  92%
# cudnn-8.1.0.77       | 610.8 MB  | #########2 |  92%
# cudnn-8.1.0.77       | 610.8 MB  | #########2 |  93%
# cudnn-8.1.0.77       | 610.8 MB  | #########2 |  93%
# cudnn-8.1.0.77       | 610.8 MB  | #########3 |  93%
# cudnn-8.1.0.77       | 610.8 MB  | #########3 |  93%
# cudnn-8.1.0.77       | 610.8 MB  | #########3 |  94%
# cudnn-8.1.0.77       | 610.8 MB  | #########3 |  94%
# cudnn-8.1.0.77       | 610.8 MB  | #########4 |  94%
# cudnn-8.1.0.77       | 610.8 MB  | #########4 |  94%
# cudnn-8.1.0.77       | 610.8 MB  | #########4 |  95%
# cudnn-8.1.0.77       | 610.8 MB  | #########4 |  95%
# cudnn-8.1.0.77       | 610.8 MB  | #########5 |  95%
# cudnn-8.1.0.77       | 610.8 MB  | #########5 |  95%
# cudnn-8.1.0.77       | 610.8 MB  | #########5 |  95%
# cudnn-8.1.0.77       | 610.8 MB  | #########5 |  96%
# cudnn-8.1.0.77       | 610.8 MB  | #########5 |  96%
# cudnn-8.1.0.77       | 610.8 MB  | #########6 |  96%
# cudnn-8.1.0.77       | 610.8 MB  | #########6 |  96%
# cudnn-8.1.0.77       | 610.8 MB  | #########6 |  97%
# cudnn-8.1.0.77       | 610.8 MB  | #########6 |  97%
# cudnn-8.1.0.77       | 610.8 MB  | #########7 |  97%
# cudnn-8.1.0.77       | 610.8 MB  | #########7 |  97%
# cudnn-8.1.0.77       | 610.8 MB  | #########7 |  98%
# cudnn-8.1.0.77       | 610.8 MB  | #########7 |  98%
# cudnn-8.1.0.77       | 610.8 MB  | #########7 |  98%
# cudnn-8.1.0.77       | 610.8 MB  | #########8 |  98%
# cudnn-8.1.0.77       | 610.8 MB  | #########8 |  98%
# cudnn-8.1.0.77       | 610.8 MB  | #########8 |  99%
# cudnn-8.1.0.77       | 610.8 MB  | #########8 |  99%
# cudnn-8.1.0.77       | 610.8 MB  | #########9 |  99%
# cudnn-8.1.0.77       | 610.8 MB  | #########9 |  99%
# cudnn-8.1.0.77       | 610.8 MB  | #########9 | 100%
# cudnn-8.1.0.77       | 610.8 MB  | #########9 | 100%
# cudnn-8.1.0.77       | 610.8 MB  | ########## | 100%
#
# ca-certificates-2023 | 151 KB    |            |   0%
# ca-certificates-2023 | 151 KB    | ########## | 100%
#
# cudatoolkit-11.2.2   | 879.9 MB  |            |   0%
# cudatoolkit-11.2.2   | 879.9 MB  |            |   0%
# cudatoolkit-11.2.2   | 879.9 MB  |            |   0%
# cudatoolkit-11.2.2   | 879.9 MB  |            |   0%
# cudatoolkit-11.2.2   | 879.9 MB  |            |   1%
# cudatoolkit-11.2.2   | 879.9 MB  |            |   1%
# cudatoolkit-11.2.2   | 879.9 MB  |            |   1%
# cudatoolkit-11.2.2   | 879.9 MB  |            |   1%
# cudatoolkit-11.2.2   | 879.9 MB  | 1          |   1%
# cudatoolkit-11.2.2   | 879.9 MB  | 1          |   1%
# cudatoolkit-11.2.2   | 879.9 MB  | 1          |   2%
# cudatoolkit-11.2.2   | 879.9 MB  | 1          |   2%
# cudatoolkit-11.2.2   | 879.9 MB  | 2          |   2%
# cudatoolkit-11.2.2   | 879.9 MB  | 2          |   2%
# cudatoolkit-11.2.2   | 879.9 MB  | 2          |   3%
# cudatoolkit-11.2.2   | 879.9 MB  | 2          |   3%
# cudatoolkit-11.2.2   | 879.9 MB  | 2          |   3%
# cudatoolkit-11.2.2   | 879.9 MB  | 3          |   3%
# cudatoolkit-11.2.2   | 879.9 MB  | 3          |   3%
# cudatoolkit-11.2.2   | 879.9 MB  | 3          |   3%
# cudatoolkit-11.2.2   | 879.9 MB  | 3          |   4%
# cudatoolkit-11.2.2   | 879.9 MB  | 3          |   4%
# cudatoolkit-11.2.2   | 879.9 MB  | 3          |   4%
# cudatoolkit-11.2.2   | 879.9 MB  | 4          |   4%
# cudatoolkit-11.2.2   | 879.9 MB  | 4          |   4%
# cudatoolkit-11.2.2   | 879.9 MB  | 4          |   4%
# cudatoolkit-11.2.2   | 879.9 MB  | 4          |   5%
# cudatoolkit-11.2.2   | 879.9 MB  | 4          |   5%
# cudatoolkit-11.2.2   | 879.9 MB  | 4          |   5%
# cudatoolkit-11.2.2   | 879.9 MB  | 5          |   5%
# cudatoolkit-11.2.2   | 879.9 MB  | 5          |   5%
# cudatoolkit-11.2.2   | 879.9 MB  | 5          |   5%
# cudatoolkit-11.2.2   | 879.9 MB  | 5          |   6%
# cudatoolkit-11.2.2   | 879.9 MB  | 5          |   6%
# cudatoolkit-11.2.2   | 879.9 MB  | 5          |   6%
# cudatoolkit-11.2.2   | 879.9 MB  | 6          |   6%
# cudatoolkit-11.2.2   | 879.9 MB  | 6          |   6%
# cudatoolkit-11.2.2   | 879.9 MB  | 6          |   6%
# cudatoolkit-11.2.2   | 879.9 MB  | 6          |   7%
# cudatoolkit-11.2.2   | 879.9 MB  | 6          |   7%
# cudatoolkit-11.2.2   | 879.9 MB  | 6          |   7%
# cudatoolkit-11.2.2   | 879.9 MB  | 7          |   7%
# cudatoolkit-11.2.2   | 879.9 MB  | 7          |   7%
# cudatoolkit-11.2.2   | 879.9 MB  | 7          |   7%
# cudatoolkit-11.2.2   | 879.9 MB  | 7          |   7%
# cudatoolkit-11.2.2   | 879.9 MB  | 7          |   8%
# cudatoolkit-11.2.2   | 879.9 MB  | 7          |   8%
# cudatoolkit-11.2.2   | 879.9 MB  | 7          |   8%
# cudatoolkit-11.2.2   | 879.9 MB  | 8          |   8%
# cudatoolkit-11.2.2   | 879.9 MB  | 8          |   8%
# cudatoolkit-11.2.2   | 879.9 MB  | 8          |   8%
# cudatoolkit-11.2.2   | 879.9 MB  | 8          |   9%
# cudatoolkit-11.2.2   | 879.9 MB  | 8          |   9%
# cudatoolkit-11.2.2   | 879.9 MB  | 8          |   9%
# cudatoolkit-11.2.2   | 879.9 MB  | 9          |   9%
# cudatoolkit-11.2.2   | 879.9 MB  | 9          |   9%
# cudatoolkit-11.2.2   | 879.9 MB  | 9          |   9%
# cudatoolkit-11.2.2   | 879.9 MB  | 9          |  10%
# cudatoolkit-11.2.2   | 879.9 MB  | 9          |  10%
# cudatoolkit-11.2.2   | 879.9 MB  | 9          |  10%
# cudatoolkit-11.2.2   | 879.9 MB  | 9          |  10%
# cudatoolkit-11.2.2   | 879.9 MB  | #          |  10%
# cudatoolkit-11.2.2   | 879.9 MB  | #          |  10%
# cudatoolkit-11.2.2   | 879.9 MB  | #          |  10%
# cudatoolkit-11.2.2   | 879.9 MB  | #          |  11%
# cudatoolkit-11.2.2   | 879.9 MB  | #          |  11%
# cudatoolkit-11.2.2   | 879.9 MB  | #          |  11%
# cudatoolkit-11.2.2   | 879.9 MB  | #1         |  11%
# cudatoolkit-11.2.2   | 879.9 MB  | #1         |  11%
# cudatoolkit-11.2.2   | 879.9 MB  | #1         |  11%
# cudatoolkit-11.2.2   | 879.9 MB  | #1         |  12%
# cudatoolkit-11.2.2   | 879.9 MB  | #1         |  12%
# cudatoolkit-11.2.2   | 879.9 MB  | #1         |  12%
# cudatoolkit-11.2.2   | 879.9 MB  | #2         |  12%
# cudatoolkit-11.2.2   | 879.9 MB  | #2         |  12%
# cudatoolkit-11.2.2   | 879.9 MB  | #2         |  12%
# cudatoolkit-11.2.2   | 879.9 MB  | #2         |  13%
# cudatoolkit-11.2.2   | 879.9 MB  | #2         |  13%
# cudatoolkit-11.2.2   | 879.9 MB  | #2         |  13%
# cudatoolkit-11.2.2   | 879.9 MB  | #3         |  13%
# cudatoolkit-11.2.2   | 879.9 MB  | #3         |  13%
# cudatoolkit-11.2.2   | 879.9 MB  | #3         |  13%
# cudatoolkit-11.2.2   | 879.9 MB  | #3         |  14%
# cudatoolkit-11.2.2   | 879.9 MB  | #3         |  14%
# cudatoolkit-11.2.2   | 879.9 MB  | #3         |  14%
# cudatoolkit-11.2.2   | 879.9 MB  | #3         |  14%
# cudatoolkit-11.2.2   | 879.9 MB  | #4         |  14%
# cudatoolkit-11.2.2   | 879.9 MB  | #4         |  14%
# cudatoolkit-11.2.2   | 879.9 MB  | #4         |  14%
# cudatoolkit-11.2.2   | 879.9 MB  | #4         |  15%
# cudatoolkit-11.2.2   | 879.9 MB  | #4         |  15%
# cudatoolkit-11.2.2   | 879.9 MB  | #4         |  15%
# cudatoolkit-11.2.2   | 879.9 MB  | #5         |  15%
# cudatoolkit-11.2.2   | 879.9 MB  | #5         |  15%
# cudatoolkit-11.2.2   | 879.9 MB  | #5         |  15%
# cudatoolkit-11.2.2   | 879.9 MB  | #5         |  16%
# cudatoolkit-11.2.2   | 879.9 MB  | #5         |  16%
# cudatoolkit-11.2.2   | 879.9 MB  | #5         |  16%
# cudatoolkit-11.2.2   | 879.9 MB  | #6         |  16%
# cudatoolkit-11.2.2   | 879.9 MB  | #6         |  16%
# cudatoolkit-11.2.2   | 879.9 MB  | #6         |  16%
# cudatoolkit-11.2.2   | 879.9 MB  | #6         |  17%
# cudatoolkit-11.2.2   | 879.9 MB  | #6         |  17%
# cudatoolkit-11.2.2   | 879.9 MB  | #6         |  17%
# cudatoolkit-11.2.2   | 879.9 MB  | #7         |  17%
# cudatoolkit-11.2.2   | 879.9 MB  | #7         |  17%
# cudatoolkit-11.2.2   | 879.9 MB  | #7         |  17%
# cudatoolkit-11.2.2   | 879.9 MB  | #7         |  18%
# cudatoolkit-11.2.2   | 879.9 MB  | #7         |  18%
# cudatoolkit-11.2.2   | 879.9 MB  | #7         |  18%
# cudatoolkit-11.2.2   | 879.9 MB  | #8         |  18%
# cudatoolkit-11.2.2   | 879.9 MB  | #8         |  18%
# cudatoolkit-11.2.2   | 879.9 MB  | #8         |  18%
# cudatoolkit-11.2.2   | 879.9 MB  | #8         |  18%
# cudatoolkit-11.2.2   | 879.9 MB  | #8         |  19%
# cudatoolkit-11.2.2   | 879.9 MB  | #8         |  19%
# cudatoolkit-11.2.2   | 879.9 MB  | #9         |  19%
# cudatoolkit-11.2.2   | 879.9 MB  | #9         |  19%
# cudatoolkit-11.2.2   | 879.9 MB  | #9         |  19%
# cudatoolkit-11.2.2   | 879.9 MB  | #9         |  20%
# cudatoolkit-11.2.2   | 879.9 MB  | #9         |  20%
# cudatoolkit-11.2.2   | 879.9 MB  | #9         |  20%
# cudatoolkit-11.2.2   | 879.9 MB  | #9         |  20%
# cudatoolkit-11.2.2   | 879.9 MB  | ##         |  20%
# cudatoolkit-11.2.2   | 879.9 MB  | ##         |  20%
# cudatoolkit-11.2.2   | 879.9 MB  | ##         |  20%
# cudatoolkit-11.2.2   | 879.9 MB  | ##         |  21%
# cudatoolkit-11.2.2   | 879.9 MB  | ##         |  21%
# cudatoolkit-11.2.2   | 879.9 MB  | ##         |  21%
# cudatoolkit-11.2.2   | 879.9 MB  | ##1        |  21%
# cudatoolkit-11.2.2   | 879.9 MB  | ##1        |  21%
# cudatoolkit-11.2.2   | 879.9 MB  | ##1        |  21%
# cudatoolkit-11.2.2   | 879.9 MB  | ##1        |  22%
# cudatoolkit-11.2.2   | 879.9 MB  | ##1        |  22%
# cudatoolkit-11.2.2   | 879.9 MB  | ##1        |  22%
# cudatoolkit-11.2.2   | 879.9 MB  | ##2        |  22%
# cudatoolkit-11.2.2   | 879.9 MB  | ##2        |  22%
# cudatoolkit-11.2.2   | 879.9 MB  | ##2        |  22%
# cudatoolkit-11.2.2   | 879.9 MB  | ##2        |  23%
# cudatoolkit-11.2.2   | 879.9 MB  | ##2        |  23%
# cudatoolkit-11.2.2   | 879.9 MB  | ##2        |  23%
# cudatoolkit-11.2.2   | 879.9 MB  | ##2        |  23%
# cudatoolkit-11.2.2   | 879.9 MB  | ##3        |  23%
# cudatoolkit-11.2.2   | 879.9 MB  | ##3        |  23%
# cudatoolkit-11.2.2   | 879.9 MB  | ##3        |  23%
# cudatoolkit-11.2.2   | 879.9 MB  | ##3        |  24%
# cudatoolkit-11.2.2   | 879.9 MB  | ##3        |  24%
# cudatoolkit-11.2.2   | 879.9 MB  | ##3        |  24%
# cudatoolkit-11.2.2   | 879.9 MB  | ##4        |  24%
# cudatoolkit-11.2.2   | 879.9 MB  | ##4        |  24%
# cudatoolkit-11.2.2   | 879.9 MB  | ##4        |  24%
# cudatoolkit-11.2.2   | 879.9 MB  | ##4        |  25%
# cudatoolkit-11.2.2   | 879.9 MB  | ##4        |  25%
# cudatoolkit-11.2.2   | 879.9 MB  | ##4        |  25%
# cudatoolkit-11.2.2   | 879.9 MB  | ##4        |  25%
# cudatoolkit-11.2.2   | 879.9 MB  | ##5        |  25%
# cudatoolkit-11.2.2   | 879.9 MB  | ##5        |  25%
# cudatoolkit-11.2.2   | 879.9 MB  | ##5        |  25%
# cudatoolkit-11.2.2   | 879.9 MB  | ##5        |  26%
# cudatoolkit-11.2.2   | 879.9 MB  | ##5        |  26%
# cudatoolkit-11.2.2   | 879.9 MB  | ##6        |  26%
# cudatoolkit-11.2.2   | 879.9 MB  | ##6        |  26%
# cudatoolkit-11.2.2   | 879.9 MB  | ##6        |  27%
# ...
# cudatoolkit-11.2.2   | 879.9 MB  | #####7     |  58%
# cudatoolkit-11.2.2   | 879.9 MB  | #####8     |  58%
# cudatoolkit-11.2.2   | 879.9 MB  | #####8     |  58%
# cudatoolkit-11.2.2   | 879.9 MB  | #####8     |  58%
# cudatoolkit-11.2.2   | 879.9 MB  | #####8     |  59%
# cudatoolkit-11.2.2   | 879.9 MB  | #####8     |  59%
# cudatoolkit-11.2.2   | 879.9 MB  | #####8     |  59%
# cudatoolkit-11.2.2   | 879.9 MB  | #####9     |  59%
# cudatoolkit-11.2.2   | 879.9 MB  | #####9     |  59%
# cudatoolkit-11.2.2   | 879.9 MB  | #####9     |  59%
# cudatoolkit-11.2.2   | 879.9 MB  | #####9     |  60%
# cudatoolkit-11.2.2   | 879.9 MB  | #####9     |  60%
# cudatoolkit-11.2.2   | 879.9 MB  | #####9     |  60%
# cudatoolkit-11.2.2   | 879.9 MB  | ######     |  60%
# cudatoolkit-11.2.2   | 879.9 MB  | ######     |  60%
# cudatoolkit-11.2.2   | 879.9 MB  | ######     |  60%
# cudatoolkit-11.2.2   | 879.9 MB  | ######     |  61%
# cudatoolkit-11.2.2   | 879.9 MB  | ######     |  61%
# cudatoolkit-11.2.2   | 879.9 MB  | ######     |  61%
# cudatoolkit-11.2.2   | 879.9 MB  | ######     |  61%
# cudatoolkit-11.2.2   | 879.9 MB  | ######1    |  61%
# cudatoolkit-11.2.2   | 879.9 MB  | ######1    |  61%
# cudatoolkit-11.2.2   | 879.9 MB  | ######1    |  61%
# cudatoolkit-11.2.2   | 879.9 MB  | ######1    |  62%
# cudatoolkit-11.2.2   | 879.9 MB  | ######1    |  62%
# cudatoolkit-11.2.2   | 879.9 MB  | ######1    |  62%
# cudatoolkit-11.2.2   | 879.9 MB  | ######2    |  62%
# cudatoolkit-11.2.2   | 879.9 MB  | ######2    |  62%
# cudatoolkit-11.2.2   | 879.9 MB  | ######2    |  62%
# cudatoolkit-11.2.2   | 879.9 MB  | ######2    |  63%
# cudatoolkit-11.2.2   | 879.9 MB  | ######2    |  63%
# cudatoolkit-11.2.2   | 879.9 MB  | ######2    |  63%
# cudatoolkit-11.2.2   | 879.9 MB  | ######3    |  63%
# cudatoolkit-11.2.2   | 879.9 MB  | ######3    |  63%
# cudatoolkit-11.2.2   | 879.9 MB  | ######3    |  63%
# cudatoolkit-11.2.2   | 879.9 MB  | ######3    |  63%
# cudatoolkit-11.2.2   | 879.9 MB  | ######3    |  64%
# cudatoolkit-11.2.2   | 879.9 MB  | ######3    |  64%
# cudatoolkit-11.2.2   | 879.9 MB  | ######3    |  64%
# cudatoolkit-11.2.2   | 879.9 MB  | ######4    |  64%
# cudatoolkit-11.2.2   | 879.9 MB  | ######4    |  64%
# cudatoolkit-11.2.2   | 879.9 MB  | ######4    |  64%
# cudatoolkit-11.2.2   | 879.9 MB  | ######4    |  65%
# cudatoolkit-11.2.2   | 879.9 MB  | ######4    |  65%
# cudatoolkit-11.2.2   | 879.9 MB  | ######4    |  65%
# cudatoolkit-11.2.2   | 879.9 MB  | ######5    |  65%
# cudatoolkit-11.2.2   | 879.9 MB  | ######5    |  65%
# cudatoolkit-11.2.2   | 879.9 MB  | ######5    |  65%
# cudatoolkit-11.2.2   | 879.9 MB  | ######5    |  65%
# cudatoolkit-11.2.2   | 879.9 MB  | ######5    |  66%
# cudatoolkit-11.2.2   | 879.9 MB  | ######5    |  66%
# cudatoolkit-11.2.2   | 879.9 MB  | ######6    |  66%
# cudatoolkit-11.2.2   | 879.9 MB  | ######6    |  66%
# cudatoolkit-11.2.2   | 879.9 MB  | ######6    |  66%
# cudatoolkit-11.2.2   | 879.9 MB  | ######6    |  66%
# cudatoolkit-11.2.2   | 879.9 MB  | ######6    |  67%
# cudatoolkit-11.2.2   | 879.9 MB  | ######6    |  67%
# cudatoolkit-11.2.2   | 879.9 MB  | ######6    |  67%
# cudatoolkit-11.2.2   | 879.9 MB  | ######7    |  67%
# cudatoolkit-11.2.2   | 879.9 MB  | ######7    |  67%
# cudatoolkit-11.2.2   | 879.9 MB  | ######7    |  67%
# cudatoolkit-11.2.2   | 879.9 MB  | ######7    |  68%
# cudatoolkit-11.2.2   | 879.9 MB  | ######7    |  68%
# cudatoolkit-11.2.2   | 879.9 MB  | ######7    |  68%
# cudatoolkit-11.2.2   | 879.9 MB  | ######8    |  68%
# cudatoolkit-11.2.2   | 879.9 MB  | ######8    |  68%
# cudatoolkit-11.2.2   | 879.9 MB  | ######8    |  68%
# cudatoolkit-11.2.2   | 879.9 MB  | ######8    |  69%
# cudatoolkit-11.2.2   | 879.9 MB  | ######8    |  69%
# cudatoolkit-11.2.2   | 879.9 MB  | ######8    |  69%
# cudatoolkit-11.2.2   | 879.9 MB  | ######8    |  69%
# cudatoolkit-11.2.2   | 879.9 MB  | ######9    |  69%
# cudatoolkit-11.2.2   | 879.9 MB  | ######9    |  69%
# cudatoolkit-11.2.2   | 879.9 MB  | ######9    |  69%
# cudatoolkit-11.2.2   | 879.9 MB  | ######9    |  70%
# cudatoolkit-11.2.2   | 879.9 MB  | ######9    |  70%
# cudatoolkit-11.2.2   | 879.9 MB  | ######9    |  70%
# cudatoolkit-11.2.2   | 879.9 MB  | #######    |  70%
# cudatoolkit-11.2.2   | 879.9 MB  | #######    |  70%
# cudatoolkit-11.2.2   | 879.9 MB  | #######    |  70%
# cudatoolkit-11.2.2   | 879.9 MB  | #######    |  71%
# cudatoolkit-11.2.2   | 879.9 MB  | #######    |  71%
# cudatoolkit-11.2.2   | 879.9 MB  | #######    |  71%
# cudatoolkit-11.2.2   | 879.9 MB  | #######1   |  71%
# cudatoolkit-11.2.2   | 879.9 MB  | #######1   |  71%
# cudatoolkit-11.2.2   | 879.9 MB  | #######1   |  71%
# cudatoolkit-11.2.2   | 879.9 MB  | #######1   |  72%
# cudatoolkit-11.2.2   | 879.9 MB  | #######1   |  72%
# cudatoolkit-11.2.2   | 879.9 MB  | #######1   |  72%
# cudatoolkit-11.2.2   | 879.9 MB  | #######2   |  72%
# cudatoolkit-11.2.2   | 879.9 MB  | #######2   |  72%
# cudatoolkit-11.2.2   | 879.9 MB  | #######2   |  72%
# cudatoolkit-11.2.2   | 879.9 MB  | #######2   |  73%
# cudatoolkit-11.2.2   | 879.9 MB  | #######2   |  73%
# cudatoolkit-11.2.2   | 879.9 MB  | #######2   |  73%
# cudatoolkit-11.2.2   | 879.9 MB  | #######2   |  73%
# cudatoolkit-11.2.2   | 879.9 MB  | #######3   |  73%
# cudatoolkit-11.2.2   | 879.9 MB  | #######3   |  73%
# cudatoolkit-11.2.2   | 879.9 MB  | #######3   |  73%
# cudatoolkit-11.2.2   | 879.9 MB  | #######3   |  74%
# cudatoolkit-11.2.2   | 879.9 MB  | #######3   |  74%
# cudatoolkit-11.2.2   | 879.9 MB  | #######3   |  74%
# cudatoolkit-11.2.2   | 879.9 MB  | #######4   |  74%
# cudatoolkit-11.2.2   | 879.9 MB  | #######4   |  74%
# cudatoolkit-11.2.2   | 879.9 MB  | #######4   |  74%
# cudatoolkit-11.2.2   | 879.9 MB  | #######4   |  75%
# cudatoolkit-11.2.2   | 879.9 MB  | #######4   |  75%
# cudatoolkit-11.2.2   | 879.9 MB  | #######4   |  75%
# cudatoolkit-11.2.2   | 879.9 MB  | #######5   |  75%
# cudatoolkit-11.2.2   | 879.9 MB  | #######5   |  75%
# cudatoolkit-11.2.2   | 879.9 MB  | #######5   |  75%
# cudatoolkit-11.2.2   | 879.9 MB  | #######5   |  76%
# cudatoolkit-11.2.2   | 879.9 MB  | #######5   |  76%
# cudatoolkit-11.2.2   | 879.9 MB  | #######5   |  76%
# cudatoolkit-11.2.2   | 879.9 MB  | #######6   |  76%
# cudatoolkit-11.2.2   | 879.9 MB  | #######6   |  76%
# cudatoolkit-11.2.2   | 879.9 MB  | #######6   |  76%
# cudatoolkit-11.2.2   | 879.9 MB  | #######6   |  76%
# cudatoolkit-11.2.2   | 879.9 MB  | #######6   |  77%
# cudatoolkit-11.2.2   | 879.9 MB  | #######6   |  77%
# cudatoolkit-11.2.2   | 879.9 MB  | #######6   |  77%
# cudatoolkit-11.2.2   | 879.9 MB  | #######7   |  77%
# cudatoolkit-11.2.2   | 879.9 MB  | #######7   |  77%
# cudatoolkit-11.2.2   | 879.9 MB  | #######7   |  77%
# cudatoolkit-11.2.2   | 879.9 MB  | #######7   |  78%
# cudatoolkit-11.2.2   | 879.9 MB  | #######7   |  78%
# cudatoolkit-11.2.2   | 879.9 MB  | #######7   |  78%
# cudatoolkit-11.2.2   | 879.9 MB  | #######8   |  78%
# cudatoolkit-11.2.2   | 879.9 MB  | #######8   |  78%
# cudatoolkit-11.2.2   | 879.9 MB  | #######8   |  78%
# cudatoolkit-11.2.2   | 879.9 MB  | #######8   |  79%
# cudatoolkit-11.2.2   | 879.9 MB  | #######8   |  79%
# cudatoolkit-11.2.2   | 879.9 MB  | #######8   |  79%
# cudatoolkit-11.2.2   | 879.9 MB  | #######8   |  79%
# cudatoolkit-11.2.2   | 879.9 MB  | #######9   |  79%
# cudatoolkit-11.2.2   | 879.9 MB  | #######9   |  79%
# cudatoolkit-11.2.2   | 879.9 MB  | #######9   |  79%
# cudatoolkit-11.2.2   | 879.9 MB  | #######9   |  80%
# cudatoolkit-11.2.2   | 879.9 MB  | #######9   |  80%
# cudatoolkit-11.2.2   | 879.9 MB  | #######9   |  80%
# cudatoolkit-11.2.2   | 879.9 MB  | ########   |  80%
# cudatoolkit-11.2.2   | 879.9 MB  | ########   |  80%
# cudatoolkit-11.2.2   | 879.9 MB  | ########   |  80%
# cudatoolkit-11.2.2   | 879.9 MB  | ########   |  81%
# cudatoolkit-11.2.2   | 879.9 MB  | ########   |  81%
# cudatoolkit-11.2.2   | 879.9 MB  | ########   |  81%
# cudatoolkit-11.2.2   | 879.9 MB  | ########1  |  81%
# cudatoolkit-11.2.2   | 879.9 MB  | ########1  |  81%
# cudatoolkit-11.2.2   | 879.9 MB  | ########1  |  81%
# cudatoolkit-11.2.2   | 879.9 MB  | ########1  |  81%
# cudatoolkit-11.2.2   | 879.9 MB  | ########1  |  82%
# cudatoolkit-11.2.2   | 879.9 MB  | ########1  |  82%
# cudatoolkit-11.2.2   | 879.9 MB  | ########1  |  82%
# cudatoolkit-11.2.2   | 879.9 MB  | ########2  |  82%
# cudatoolkit-11.2.2   | 879.9 MB  | ########2  |  82%
# cudatoolkit-11.2.2   | 879.9 MB  | ########2  |  82%
# cudatoolkit-11.2.2   | 879.9 MB  | ########2  |  83%
# cudatoolkit-11.2.2   | 879.9 MB  | ########2  |  83%
# cudatoolkit-11.2.2   | 879.9 MB  | ########2  |  83%
# cudatoolkit-11.2.2   | 879.9 MB  | ########3  |  83%
# cudatoolkit-11.2.2   | 879.9 MB  | ########3  |  83%
# cudatoolkit-11.2.2   | 879.9 MB  | ########3  |  83%
# cudatoolkit-11.2.2   | 879.9 MB  | ########3  |  83%
# cudatoolkit-11.2.2   | 879.9 MB  | ########3  |  84%
# cudatoolkit-11.2.2   | 879.9 MB  | ########3  |  84%
# cudatoolkit-11.2.2   | 879.9 MB  | ########4  |  84%
# cudatoolkit-11.2.2   | 879.9 MB  | ########4  |  84%
# cudatoolkit-11.2.2   | 879.9 MB  | ########4  |  84%
# cudatoolkit-11.2.2   | 879.9 MB  | ########4  |  84%
# cudatoolkit-11.2.2   | 879.9 MB  | ########4  |  85%
# cudatoolkit-11.2.2   | 879.9 MB  | ########4  |  85%
# cudatoolkit-11.2.2   | 879.9 MB  | ########4  |  85%
# cudatoolkit-11.2.2   | 879.9 MB  | ########5  |  85%
# cudatoolkit-11.2.2   | 879.9 MB  | ########5  |  85%
# cudatoolkit-11.2.2   | 879.9 MB  | ########5  |  85%
# cudatoolkit-11.2.2   | 879.9 MB  | ########5  |  86%
# cudatoolkit-11.2.2   | 879.9 MB  | ########5  |  86%
# cudatoolkit-11.2.2   | 879.9 MB  | ########5  |  86%
# cudatoolkit-11.2.2   | 879.9 MB  | ########6  |  86%
# cudatoolkit-11.2.2   | 879.9 MB  | ########6  |  86%
# cudatoolkit-11.2.2   | 879.9 MB  | ########6  |  86%
# cudatoolkit-11.2.2   | 879.9 MB  | ########6  |  86%
# cudatoolkit-11.2.2   | 879.9 MB  | ########6  |  87%
# cudatoolkit-11.2.2   | 879.9 MB  | ########6  |  87%
# cudatoolkit-11.2.2   | 879.9 MB  | ########6  |  87%
# cudatoolkit-11.2.2   | 879.9 MB  | ########7  |  87%
# cudatoolkit-11.2.2   | 879.9 MB  | ########7  |  87%
# cudatoolkit-11.2.2   | 879.9 MB  | ########7  |  87%
# cudatoolkit-11.2.2   | 879.9 MB  | ########7  |  88%
# cudatoolkit-11.2.2   | 879.9 MB  | ########7  |  88%
# cudatoolkit-11.2.2   | 879.9 MB  | ########7  |  88%
# cudatoolkit-11.2.2   | 879.9 MB  | ########8  |  88%
# cudatoolkit-11.2.2   | 879.9 MB  | ########8  |  88%
# cudatoolkit-11.2.2   | 879.9 MB  | ########8  |  88%
# cudatoolkit-11.2.2   | 879.9 MB  | ########8  |  89%
# cudatoolkit-11.2.2   | 879.9 MB  | ########8  |  89%
# cudatoolkit-11.2.2   | 879.9 MB  | ########8  |  89%
# cudatoolkit-11.2.2   | 879.9 MB  | ########9  |  89%
# cudatoolkit-11.2.2   | 879.9 MB  | ########9  |  89%
# cudatoolkit-11.2.2   | 879.9 MB  | ########9  |  90%
# cudatoolkit-11.2.2   | 879.9 MB  | ########9  |  90%
# cudatoolkit-11.2.2   | 879.9 MB  | #########  |  90%
# cudatoolkit-11.2.2   | 879.9 MB  | #########  |  90%
# cudatoolkit-11.2.2   | 879.9 MB  | #########  |  90%
# cudatoolkit-11.2.2   | 879.9 MB  | #########  |  91%
# cudatoolkit-11.2.2   | 879.9 MB  | #########  |  91%
# cudatoolkit-11.2.2   | 879.9 MB  | #########  |  91%
# cudatoolkit-11.2.2   | 879.9 MB  | #########1 |  91%
# cudatoolkit-11.2.2   | 879.9 MB  | #########1 |  91%
# cudatoolkit-11.2.2   | 879.9 MB  | #########1 |  91%
# cudatoolkit-11.2.2   | 879.9 MB  | #########1 |  92%
# cudatoolkit-11.2.2   | 879.9 MB  | #########1 |  92%
# cudatoolkit-11.2.2   | 879.9 MB  | #########1 |  92%
# cudatoolkit-11.2.2   | 879.9 MB  | #########2 |  92%
# cudatoolkit-11.2.2   | 879.9 MB  | #########2 |  92%
# cudatoolkit-11.2.2   | 879.9 MB  | #########2 |  92%
# cudatoolkit-11.2.2   | 879.9 MB  | #########2 |  93%
# cudatoolkit-11.2.2   | 879.9 MB  | #########2 |  93%
# cudatoolkit-11.2.2   | 879.9 MB  | #########2 |  93%
# cudatoolkit-11.2.2   | 879.9 MB  | #########3 |  93%
# cudatoolkit-11.2.2   | 879.9 MB  | #########3 |  93%
# cudatoolkit-11.2.2   | 879.9 MB  | #########3 |  93%
# cudatoolkit-11.2.2   | 879.9 MB  | #########3 |  93%
# cudatoolkit-11.2.2   | 879.9 MB  | #########3 |  94%
# cudatoolkit-11.2.2   | 879.9 MB  | #########3 |  94%
# cudatoolkit-11.2.2   | 879.9 MB  | #########3 |  94%
# cudatoolkit-11.2.2   | 879.9 MB  | #########4 |  94%
# cudatoolkit-11.2.2   | 879.9 MB  | #########4 |  94%
# cudatoolkit-11.2.2   | 879.9 MB  | #########4 |  95%
# cudatoolkit-11.2.2   | 879.9 MB  | #########4 |  95%
# cudatoolkit-11.2.2   | 879.9 MB  | #########4 |  95%
# cudatoolkit-11.2.2   | 879.9 MB  | #########5 |  95%
# cudatoolkit-11.2.2   | 879.9 MB  | #########5 |  95%
# cudatoolkit-11.2.2   | 879.9 MB  | #########5 |  95%
# cudatoolkit-11.2.2   | 879.9 MB  | #########5 |  96%
# cudatoolkit-11.2.2   | 879.9 MB  | #########5 |  96%
# cudatoolkit-11.2.2   | 879.9 MB  | #########5 |  96%
# cudatoolkit-11.2.2   | 879.9 MB  | #########6 |  96%
# cudatoolkit-11.2.2   | 879.9 MB  | #########6 |  96%
# cudatoolkit-11.2.2   | 879.9 MB  | #########6 |  96%
# cudatoolkit-11.2.2   | 879.9 MB  | #########6 |  97%
# cudatoolkit-11.2.2   | 879.9 MB  | #########6 |  97%
# cudatoolkit-11.2.2   | 879.9 MB  | #########6 |  97%
# cudatoolkit-11.2.2   | 879.9 MB  | #########7 |  97%
# cudatoolkit-11.2.2   | 879.9 MB  | #########7 |  97%
# cudatoolkit-11.2.2   | 879.9 MB  | #########7 |  97%
# cudatoolkit-11.2.2   | 879.9 MB  | #########7 |  98%
# cudatoolkit-11.2.2   | 879.9 MB  | #########7 |  98%
# cudatoolkit-11.2.2   | 879.9 MB  | #########7 |  98%
# cudatoolkit-11.2.2   | 879.9 MB  | #########8 |  98%
# cudatoolkit-11.2.2   | 879.9 MB  | #########8 |  98%
# cudatoolkit-11.2.2   | 879.9 MB  | #########8 |  98%
# cudatoolkit-11.2.2   | 879.9 MB  | #########8 |  99%
# cudatoolkit-11.2.2   | 879.9 MB  | #########8 |  99%
# cudatoolkit-11.2.2   | 879.9 MB  | #########8 |  99%
# cudatoolkit-11.2.2   | 879.9 MB  | #########8 |  99%
# cudatoolkit-11.2.2   | 879.9 MB  | #########9 |  99%
# cudatoolkit-11.2.2   | 879.9 MB  | #########9 |  99%
# cudatoolkit-11.2.2   | 879.9 MB  | #########9 |  99%
# cudatoolkit-11.2.2   | 879.9 MB  | #########9 | 100%
# cudatoolkit-11.2.2   | 879.9 MB  | #########9 | 100%
# cudatoolkit-11.2.2   | 879.9 MB  | #########9 | 100%
# cudatoolkit-11.2.2   | 879.9 MB  | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... "By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html"
#
# "By downloading and using the cuDNN conda packages, you accept the terms and conditions of the NVIDIA cuDNN EULA - https://docs.nvidia.com/deeplearning/cudnn/sla/index.html"
#
# done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 23.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
# Requirement already satisfied: pip in c:\users\nxcle\anaconda3\envs\spartan\lib\site-packages (23.3.1)
# Collecting pip
#   Downloading pip-23.3.2-py3-none-any.whl.metadata (3.5 kB)
# Downloading pip-23.3.2-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.1 MB 660.6 kB/s eta 0:00:04
#    ----- ---------------------------------- 0.3/2.1 MB 3.8 MB/s eta 0:00:01
#    ------------- -------------------------- 0.7/2.1 MB 5.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.2/2.1 MB 6.9 MB/s eta 0:00:01
#    -------------------------------- ------- 1.7/2.1 MB 7.8 MB/s eta 0:00:01
#    ------------------------------------ --- 1.9/2.1 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 6.1 MB/s eta 0:00:00
# ERROR: To modify pip, please run the following command:
# c:\Users\nxcle\anaconda3\envs\spartan\python.exe -m pip install --upgrade pip
# The system cannot find the file specified.

# %%
from train_tf import *
from tensorflow.keras.callbacks import TensorBoard
from parameters import *
import socket
import tensorflow as tf

import datetime
import os

# %%
par = get_main_experiments(7, train_gpu=True, tensorboard=True)
par.enc.opt_model_type = OptModelType.OPT_125m
par.enc.news_source = NewsSource.NEWS_SINGLE

# Training args
par.train.use_tf_models = True
par.train.l1_ratio = [0.5]
par.train.batch_size = 128
par.train.monitor_metric = 'val_auc'
par.train.patience = 3
par.train.max_epoch = 2
par.train.abny = False

# par.train.T_train = 1


# Skip Normalisation
# par.train.norm = None

start = time.time()

temp_save_dir = par.get_res_dir()
print(temp_save_dir, flush=True)
already_processed = os.listdir(temp_save_dir)
save_name = f'{par.grid.year_id}.p'
print('save_name', save_name, "already_processed", already_processed)
if save_name in already_processed:
    print(f'Already processed {save_name}', flush=True)
else:
    trainer = PipelineTrainer(par)
    trainer.def_create_the_datasets(
        filter_func=lambda x: 'mean' in x.split('/')[-1].split('_'),  # filter by 'mean' in file name
    )
    print('Preprocessing time', np.round((time.time() - start) / 60, 5), 'min', flush=True)
# Out:
# START WORKING ON  7
# comb 8 / 264
# /data/gpfs/projects/punim2039/EightK/res/temp/vec_pred/510fee073a185095f011c22a38313a6a314dc2cc3676553642dfe936b6d278bb/OPT_125m/NEWS_SINGLE/
# save_name 2019.p already_processed []
# tensorboard --logdir=C:\Users\nxcle\Projects\spartan_8k\EightK\logs\fit\20240129-232304
# Preprocessing time 0.01239 min

# %%
model = trainer.train_model(tr_data=trainer.train_val_dataset, val_data=None, reg_to_use=tf.keras.regularizers.l1_l2(0.001, 0.001))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, 768)              1537
#  n)
#
#  dense (Dense)               (None, 1)                 769
#
# =================================================================
# Total params: 2,306
# Trainable params: 769
# Non-trainable params: 1,537
# _________________________________________________________________
# Epoch 1/2
#   13987/Unknown - 653s 46ms/step - loss: 0.6976 - accuracy: 0.5384 - auc: 0.5434 - precision: 0.5510 - recall: 0.6881

# %%
model1_evaluation_results_val = model.evaluate(
    trainer.val_dataset,
    return_dict=True
)
model1_evaluation_results_val

# %%
model1_evaluation_results_test = model.evaluate(
    trainer.test_dataset,
    return_dict=True
)
model1_evaluation_results_test
# Out:
# 4304/4304 [==============================] - 148s 20ms/step - loss: 0.7146 - accuracy: 0.5377 - auc: 0.4950 - precision_1: 0.5419 - recall_1: 0.9417
# {'loss': 0.7146130204200745,
#  'accuracy': 0.5377008318901062,
#  'auc': 0.49495214223861694,
#  'precision_1': 0.5419256687164307,
#  'recall_1': 0.9417335391044617}

# %%
trainer.model = model
trainer.get_prediction_on_test_sample()
# Out:
# 4304/4304 [==============================] - 80s 3ms/step
# 4304/4304 [==============================] - 151s 20ms/step - loss: 0.7146 - accuracy: 0.5377 - auc: 0.4950 - precision_1: 0.5419 - recall_1: 0.9417
# ####### SANITY CHECK
# Accuracy from .evaluate: 0.5377008318901062
# AUC from .evaluate: 0.49495214223861694
# Accuracy from .df: 0.537701
#                                                        id                 date  ticker  y_true  y_pred  y_pred_prb  accuracy
# 0       APN003RW8_19030419KKbgxzjEsZU97w8+QLlkLLmQcWbS...  2019-03-04 00:00:00   13928       1       1    0.663844      True
# 1       APN003RW8_1903042PBBhDz3eWUK1mUFX83o0MfkCcZTiJ...  2019-03-04 00:00:00   13928       1       1    0.519204      True
# 2       APN00001Z_1903052vUuZe1H/yDMlkTk6z3NnAOwP67S4f...  2019-03-05 00:00:00   25785       0       1    0.540558     False
# 3       A5N20D00C_1903051PbdzJf8U29nnxcOY+Hmb7zeZPLjjz...  2019-03-05 00:00:00   11850       0       1    0.675039     False
# 4       A5N20D00C_1903052/EdmDbsLU1q0g3iawPMuJPcqFDs12...  2019-03-05 00:00:00   11850       0       1    0.558548     False
# ...                                                   ...                  ...     ...     ...     ...         ...       ...
# 550818  GNX1KJSjR_1904302u1Eqj8eMe+u+qTRXNBVqIPH0yrNcR...  2019-04-30 00:00:00   18397       1       1    0.550513      True
# 550819  GNE4wH4vk_1904302utC01nS8KCeukGVa80HD2Xt2mV9A7...  2019-04-30 00:00:00   93089       1       1    0.538122      True
# 550820  GNE9jqCZN_1904302m3V+3dlGiYreBpg80QhQLCb99DRi4...  2019-04-30 00:00:00   81677       1       1    0.543524      True
# 550821  CNW57M0ra_1904302aT1T5CW6OFbwbnKhKB21fcZ1j61ON...  2019-04-30 00:00:00   81527       1       1    0.555791      True
# 550822  GNEDMmTc__1904302XYEbFiZYKQk69pL2BQccpKp4B1D64...  2019-04-30 00:00:00   16384       1       1    0.560305      True
#
# [550823 rows x 7 columns]

# %% [markdown]
# ## Results

# %%
from data import *
from sklearn.metrics import confusion_matrix
from matplotlib import pyplot as plt
import swifter
from tqdm import tqdm
import regex as re

# %%
args = didi.parse()
par = Params()
data = Data(par)

# load_dir = '/data/gpfs/projects/punim2119/EightK/res/temp/vec_pred/5e8b285d69edeee2833f1f2aa4d81ef00f787ed5188fcf557a54d04ad73af547/OPT_125m/NEWS_SINGLE/' # No Normalisation, Ret
load_dir = '/data/gpfs/projects/punim2119/EightK/res/temp/vec_pred/23c308fffeb08a56e3eb4b0717303816005bafc70a823f1a45b92c2c9027ab88/OPT_125m/NEWS_SINGLE/' # No Normalisation, Abret

model_outputs = [os.path.join(load_dir, f) for f in os.listdir(load_dir) if re.match(r'\d+.p$', f)]
model_outputs
# Out:
# []

# %%
crsp = data.load_crsp_daily()
crsp_sorted = crsp.sort_values(by=['permno', 'date'])
crsp_sorted.head(10)
# Out:
#    permno       date ticker    prc        ret    bid    ask  shrout
# 0   10001 1993-01-04   GFGC  14.50   0.035714  14.00  14.50  1080.0
# 1   10001 1993-01-05   GFGC -14.25  -0.017241  14.00  14.50  1080.0
# 2   10001 1993-01-06   GFGC -14.25   0.000000  14.00  14.50  1080.0
# 3   10001 1993-01-07   GFGC  14.50   0.017544  14.00  14.50  1080.0
# 4   10001 1993-01-08   GFGC  14.50   0.000000  14.00  14.50  1080.0
# 5   10001 1993-01-11   GFGC  14.50   0.000000  14.00  14.50  1080.0
# 6   10001 1993-01-12   GFGC -14.25  -0.017241  14.00  14.50  1080.0
# 7   10001 1993-01-13   GFGC  13.75  -0.035088  13.75  14.25  1080.0
# 8   10001 1993-01-14   GFGC  13.75   0.000000  13.75  14.25  1080.0
# 9   10001 1993-01-15   GFGC -14.00   0.018182  13.75  14.25  1080.0

# %%
# read df from pickle
#date should be in datetime64[ns]
df = pd.read_pickle(model_outputs[0]).rename(columns={'ticker':'permno'})
df['date'] = pd.to_datetime(df['date'])
df.rename(columns={'date': 'date_news'}, inplace=True)
df
# Out:
#                                                        id  date_news  permno  y_true  y_pred  y_pred_prb  accuracy
# 0       APN003RW8_19030419KKbgxzjEsZU97w8+QLlkLLmQcWbS... 2019-03-04   13928       1       1    0.689848      True
# 1       APN003RW8_1903042PBBhDz3eWUK1mUFX83o0MfkCcZTiJ... 2019-03-04   13928       1       1    0.518702      True
# 2       APN00001Z_1903052vUuZe1H/yDMlkTk6z3NnAOwP67S4f... 2019-03-05   25785       0       1    0.551799     False
# 3       A5N20D00C_1903051PbdzJf8U29nnxcOY+Hmb7zeZPLjjz... 2019-03-05   11850       0       1    0.708588     False
# 4       A5N20D00C_1903052/EdmDbsLU1q0g3iawPMuJPcqFDs12... 2019-03-05   11850       0       1    0.539488     False
# ...                                                   ...        ...     ...     ...     ...         ...       ...
# 550818  GNX1KJSjR_1904302u1Eqj8eMe+u+qTRXNBVqIPH0yrNcR... 2019-04-30   18397       1       1    0.533143      True
# 550819  GNE4wH4vk_1904302utC01nS8KCeukGVa80HD2Xt2mV9A7... 2019-04-30   93089       1       1    0.522192      True
# 550820  GNE9jqCZN_1904302m3V+3dlGiYreBpg80QhQLCb99DRi4... 2019-04-30   81677       1       1    0.524450      True
# 550821  CNW57M0ra_1904302aT1T5CW6OFbwbnKhKB21fcZ1j61ON... 2019-04-30   81527       1       1    0.530021      True
# 550822  GNEDMmTc__1904302XYEbFiZYKQk69pL2BQccpKp4B1D64... 2019-04-30   16384       1       1    0.531343      True
#
# [550823 rows x 7 columns]

# %%
df['accuracy'].mean()
# Out:
# 0.538038535064803

# %%
n_days_ahead = 1

print('Creating permno mapping')
crsp_grouped = crsp_sorted.groupby('permno')
permno_mapping = {}
permno_date_to_index_mapping = {}  # New mapping for date to index

for permno, group in tqdm(crsp_grouped):
    records = group[['date', 'prc', 'ret', 'bid', 'ask', 'shrout']].to_records(index=False)
    permno_mapping[permno] = records
    permno_date_to_index_mapping[permno] = {date: idx for idx, date in enumerate(group['date'])}
# Out:
# Creating permno mapping
# 100%|██████████| 14658/14658 [00:53<00:00, 275.22it/s]

# %%
# Function to perform binary search and get nth day return
def get_nth_day_return(row):
    permno = row['permno']
    date_news = row['date_news']

    trading_days = permno_mapping.get(permno, None)
    date_to_index = permno_date_to_index_mapping.get(permno, {})

    if trading_days is not None and date_news in date_to_index:
        start_index = date_to_index[date_news]
        nth_index = start_index + n_days_ahead

        if nth_index < len(trading_days):
            nth_day_data = trading_days[nth_index]
            return pd.Series({
                'date': nth_day_data.date,
                'prc': nth_day_data.prc,
                'ret': nth_day_data.ret,
                'bid': nth_day_data.bid,
                'ask': nth_day_data.ask,
                'shrout': nth_day_data.shrout
            })
    # Return default values if conditions are not met
    return pd.Series({
        'date': pd.NaT,
        'prc': None,
        'ret': None,
        'bid': None,
        'ask': None,
        'shrout': None
    })

tqdm.pandas(desc="Processing rows")
additional_columns = df.progress_apply(get_nth_day_return, axis=1)
for col in ['prc', 'ret', 'bid', 'ask', 'shrout']:
    additional_columns[col] = pd.to_numeric(additional_columns[col], errors='coerce')
df_merged = pd.concat([df, additional_columns], axis=1)
df_merged.rename(columns={'date': 'date_trade'}, inplace=True)
df_merged
# Out:
# Processing rows: 100%|██████████| 550823/550823 [01:13<00:00, 7508.50it/s]
#                                                        id  date_news  permno  y_true  y_pred  y_pred_prb  accuracy date_trade     prc       ret     bid     ask     shrout
# 0       APN003RW8_19030419KKbgxzjEsZU97w8+QLlkLLmQcWbS... 2019-03-04   13928       1       1    0.689848      True 2019-03-05   69.01 -0.012732   69.00   69.01  1134404.0
# 1       APN003RW8_1903042PBBhDz3eWUK1mUFX83o0MfkCcZTiJ... 2019-03-04   13928       1       1    0.518702      True 2019-03-05   69.01 -0.012732   69.00   69.01  1134404.0
# 2       APN00001Z_1903052vUuZe1H/yDMlkTk6z3NnAOwP67S4f... 2019-03-05   25785       0       1    0.551799     False 2019-03-06    8.58 -0.021665    8.58    8.59  3907700.0
# 3       A5N20D00C_1903051PbdzJf8U29nnxcOY+Hmb7zeZPLjjz... 2019-03-05   11850       0       1    0.708588     False 2019-03-06   79.28 -0.011348   79.26   79.27  4237000.0
# 4       A5N20D00C_1903052/EdmDbsLU1q0g3iawPMuJPcqFDs12... 2019-03-05   11850       0       1    0.539488     False 2019-03-06   79.28 -0.011348   79.26   79.27  4237000.0
# ...                                                   ...        ...     ...     ...     ...         ...       ...        ...     ...       ...     ...     ...        ...
# 550818  GNX1KJSjR_1904302u1Eqj8eMe+u+qTRXNBVqIPH0yrNcR... 2019-04-30   18397       1       1    0.533143      True 2019-05-01   13.64  0.000734   13.59   13.85    17067.0
# 550819  GNE4wH4vk_1904302utC01nS8KCeukGVa80HD2Xt2mV9A7... 2019-04-30   93089       1       1    0.522192      True 2019-05-01  139.88 -0.008927  139.81  139.87   163666.0
# 550820  GNE9jqCZN_1904302m3V+3dlGiYreBpg80QhQLCb99DRi4... 2019-04-30   81677       1       1    0.524450      True 2019-05-01   75.11  0.014041   75.10   75.11   162818.0
# 550821  CNW57M0ra_1904302aT1T5CW6OFbwbnKhKB21fcZ1j61ON... 2019-04-30   81527       1       1    0.530021      True 2019-05-01    2.05 -0.023810    2.04    2.05    71896.0
# 550822  GNEDMmTc__1904302XYEbFiZYKQk69pL2BQccpKp4B1D64... 2019-04-30   16384       1       1    0.531343      True 2019-05-01    4.66  0.004310    4.64    4.66    64263.0
#
# [550823 rows x 13 columns]

# %%
df_grouped =df_merged.groupby(['permno','date_news'])[['ret','y_pred_prb','y_true', 'prc']].mean().reset_index()

df_grouped['year'] = df_grouped['date_news'].dt.year
print(df_grouped.groupby('year')['y_pred_prb'].mean())
df_grouped['tresh'] = df_grouped.groupby('year')['y_pred_prb'].transform('mean')
# Out:
# year
# 2019    0.584544
# Name: y_pred_prb, dtype: float32

# %%
df_grouped['pred'] = df_grouped['y_pred_prb']>df_grouped['tresh']
# df_grouped['pred'] = df_grouped['y_pred_prb']>0.5
df_grouped['accuracy']=df_grouped['pred']==df_grouped['y_true']
df_grouped['accuracy'].mean()
# Out:
# 0.49809466933981716

# %%
df_merged['accuracy'].mean()
# Out:
# 0.538038535064803

# %%
df_grouped.groupby('date_news')['permno'].count().plot()
df_grouped['pct']=df_grouped.groupby('date_news')['y_pred_prb'].rank(pct=True)

# %%
df_grouped
# Out:
#         permno  date_news       ret  y_pred_prb  y_true        prc  year     tresh   pred  accuracy       pct  pos
# 0        10026 2019-01-16  0.013348    0.529996     0.0  145.75999  2019  0.584544  False      True  0.296512    0
# 1        10026 2019-01-28  0.120143    0.643932     0.0  156.82001  2019  0.584544   True     False  0.802120    1
# 2        10026 2019-01-29 -0.040301    0.658314     1.0  150.50000  2019  0.584544   True      True  0.825944    1
# 3        10026 2019-01-31  0.002915    0.720898     1.0  154.80000  2019  0.584544   True      True  0.998258    1
# 4        10026 2019-02-06 -0.011565    0.531837     0.0  156.41000  2019  0.584544  False      True  0.315708    0
# ...        ...        ...       ...         ...     ...        ...   ...       ...    ...       ...       ...  ...
# 140653   93436 2019-12-24  0.013380    0.630635     1.0  430.94000  2019  0.584544   True      True  0.666667    0
# 140654   93436 2019-12-26 -0.001299    0.632636     1.0  430.38000  2019  0.584544   True      True  0.631579    0
# 140655   93436 2019-12-27 -0.036433    0.597291     0.0  414.70001  2019  0.584544   True     False  0.500000    0
# 140656   93436 2019-12-30  0.008753    0.635464     0.0  418.32999  2019  0.584544   True     False  0.706667    0
# 140657   93436 2019-12-31  0.028518    0.552373     1.0  430.26001  2019  0.584544  False     False  0.477419    0
#
# [140658 rows x 12 columns]

# %%
confusion_matrix(df_grouped['y_true'], df_grouped['pred'])
# Out:
# array([[33820, 30919],
#        [39678, 36241]], dtype=int64)

# %%
df_grouped.groupby(['date_news'])['ret'].mean().cumsum().plot()
# Out:
# <Axes: xlabel='date_news'>

# %%
tresh = 0.2
df_grouped['pos'] = 1*(df_grouped['pct']>(1-tresh)) - (df_grouped['pct']<=tresh)*1
ret=df_grouped.groupby(['date_news','pos'])['ret'].mean().reset_index().pivot(columns='pos',index='date_news',values='ret')
ret[0] = ret[1]-ret[-1]
ret.cumsum().plot()
sh = np.sqrt(252)*(ret.mean()/ret.std()).round(3)
plt.title(f'model_index {"LR"} sharpe: {np.round(sh[0],3)}')
plt.show()

# %%
# index ret by [1, -1, 0]
ret_formated = ret[[1, -1, 0]]
sh_formated = np.sqrt(252)*(ret_formated.mean()/ret_formated.std()).round(3)
print("        ", "Long", "Short", "L-S", sep="\t")
print("Return: ", *list((252 * ret_formated.mean()).round(3)), sep="\t")
print("Std:    ", *list((np.sqrt(252)*ret_formated.std()).round(3)), sep="\t")
print("Sharpe: ", *list(sh_formated.round(3)), sep="\t")
# Out:
#         	Long	Short	L-S
# Return: 	0.014	0.408	-0.393
# Std:    	0.197	0.164	0.125
# Sharpe: 	0.079	2.476	-3.159
